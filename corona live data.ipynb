# %%
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
url = 'https://www.worldometers.info/coronavirus/#countries'
html_page = requests.get(url).text

# %%
soup = BeautifulSoup(html_page,'lxml')

# %%
get_table = soup.find("table",id="main_table_countries_today")

# %%
get_table_data = get_table.tbody.find_all("tr")

# %%
dic = {}

for i in range(len(get_table_data)):
    try:
        key = get_table_data[i].find_all("a",href=True)[0].string
    except:
        key = get_table_data[i].find_all("td")[0].string
        
    values = [j.string for j in get_table_data[i].find_all('td')]
    
    dic[key] = values
    
pd.DataFrame(dic).iloc[1:,:]
# Out:
#            NaN            USA         Brazil       India      Russia  \
# 1        World            USA         Brazil       India      Russia
# 2   22,069,519      5,612,027      3,363,235   2,706,450     932,493
# 3      +26,133           None           None      +4,846      +4,748
# 4      777,755       173,716        108,654      51,955      15,872
# 5         +679           None           None         +30        +132
# 6   14,807,868      2,973,587      2,478,494   1,978,747     742,628
# 7      +23,159           None           None      +2,499      +6,527
# 8    6,483,896      2,464,724        776,087     675,748     173,993
# 9       62,051         17,190          8,318       8,944       2,300
# 10       2,831         16,942         15,808       1,959       6,389
# 11        99.8            524            511          38         109
# 12        None     71,687,781     13,464,336  30,941,264  32,900,000
# 13        None        216,412         63,285      22,393     225,431
# 14        None           None           None        None        None
# 15         All  North America  South America        Asia      Europe
# 16          \n             59             63         511         157
# 17        None          1,907          1,958      26,595       9,195
# 18        None              5             16          45           4
#
#     South Africa           Peru         Mexico       Colombia          Chile  \
# 1   South Africa           Peru         Mexico       Colombia          Chile
# 2        589,886        541,493        525,733        476,660        387,502
# 3           None           None         +3,571           None           None
# 4        11,982         26,481         57,023         15,372         10,513
# 5           None           None           +266           None           None
# 6        477,671        370,717        359,347        301,525        360,385
# 7           None           None         +4,246           None           None
# 8        100,233        144,295        109,363        159,763         16,604
# 9            539          1,524          3,536          1,493          1,177
# 10         9,930         16,394          4,072          9,355         20,248
# 11           202            802            442            302            549
# 12     3,415,670      2,793,614      1,181,695      2,259,743      2,044,880
# 13        57,499         84,578          9,153         44,350        106,852
# 14          None           None           None           None           None
# 15        Africa  South America  North America  South America  South America
# 16           101             61            246            107             49
# 17         4,958          1,247          2,264          3,315          1,820
# 18            17             12            109             23              9
#
#     ...     Montserrat  Caribbean Netherlands  Falkland Islands  Vatican City  \
# 1   ...     Montserrat  Caribbean Netherlands  Falkland Islands  Vatican City
# 2   ...             13                     13                13            12
# 3   ...           None                   None              None          None
# 4   ...             1
# 5   ...           None                   None              None          None
# 6   ...             12                      7                13            12
# 7   ...           None                   None              None          None
# 8   ...              0                      6                 0             0
# 9   ...           None                   None              None          None
# 10  ...          2,604                    495             3,723        14,981
# 11  ...            200                   None              None          None
# 12  ...             61                    424             2,256          None
# 13  ...         12,220                 16,150           646,048          None
# 14  ...           None                   None              None          None
# 15  ...  North America          North America     South America        Europe
# 16  ...            384                  2,020               269            67
# 17  ...          4,992                   None              None          None
# 18  ...             82                     62                 2          None
#
#     Western Sahara         211  British Virgin Islands  Saint Pierre Miquelon  \
# 1   Western Sahara  MS Zaandam  British Virgin Islands  Saint Pierre Miquelon
# 2               10           9                       9                      4
# 3             None        None                    None                   None
# 4               1           2                       1
# 5             None        None                    None                   None
# 6                8        None                       7                      1
# 7             None        None                    None                   None
# 8                1           7                       1                      3
# 9             None        None                    None                   None
# 10              17        None                     297                    691
# 11               2        None                      33                   None
# 12            None        None                   1,522                   None
# 13            None        None                  50,302                   None
# 14            None                                None                   None
# 15          Africa        None           North America          North America
# 16          59,913        None                   3,362                  1,448
# 17         599,125        None                  30,257                   None
# 18            None        None                      20                   None
#
#          Anguilla           China
# 1        Anguilla           China
# 2               3          84,871
# 3            None             +22
# 4                          4,634
# 5            None            None
# 6               3          79,642
# 7            None             +39
# 8               0             595
# 9            None              27
# 10            200              59
# 11           None               3
# 12            662      90,410,000
# 13         44,075          62,814
# 14           None  1,439,323,776
# 15  North America            Asia
# 16          5,007          16,959
# 17           None         310,601
# 18             23              16
#
# [18 rows x 216 columns]

# %%
pd.DataFrame(dic).iloc[1:,:].T
# Out:
#                                              1           2        3         4  \
# NaN                                      World  22,069,519  +26,133   777,755
# USA                                        USA   5,612,027     None  173,716
# Brazil                                  Brazil   3,363,235     None  108,654
# India                                    India   2,706,450   +4,846   51,955
# Russia                                  Russia     932,493   +4,748   15,872
# ...                                        ...         ...      ...       ...
# 211                                 MS Zaandam           9     None        2
# British Virgin Islands  British Virgin Islands           9     None        1
# Saint Pierre Miquelon    Saint Pierre Miquelon           4     None
# Anguilla                              Anguilla           3     None
# China                                    China      84,871      +22    4,634
#
#                            5           6        7          8       9      10  \
# NaN                     +679  14,807,868  +23,159  6,483,896  62,051   2,831
# USA                     None   2,973,587     None  2,464,724  17,190  16,942
# Brazil                  None   2,478,494     None    776,087   8,318  15,808
# India                    +30   1,978,747   +2,499    675,748   8,944   1,959
# Russia                  +132     742,628   +6,527    173,993   2,300   6,389
# ...                      ...         ...      ...        ...     ...     ...
# 211                     None        None     None          7    None    None
# British Virgin Islands  None           7     None          1    None     297
# Saint Pierre Miquelon   None           1     None          3    None     691
# Anguilla                None           3     None          0    None     200
# China                   None      79,642      +39        595      27      59
#
#                           11          12       13              14  \
# NaN                     99.8        None     None            None
# USA                      524  71,687,781  216,412            None
# Brazil                   511  13,464,336   63,285            None
# India                     38  30,941,264   22,393            None
# Russia                   109  32,900,000  225,431            None
# ...                      ...         ...      ...             ...
# 211                     None        None     None
# British Virgin Islands    33       1,522   50,302            None
# Saint Pierre Miquelon   None        None     None            None
# Anguilla                None         662   44,075            None
# China                      3  90,410,000   62,814  1,439,323,776
#
#                                    15      16       17    18
# NaN                               All      \n     None  None
# USA                     North America      59    1,907     5
# Brazil                  South America      63    1,958    16
# India                            Asia     511   26,595    45
# Russia                         Europe     157    9,195     4
# ...                               ...     ...      ...   ...
# 211                              None    None     None  None
# British Virgin Islands  North America   3,362   30,257    20
# Saint Pierre Miquelon   North America   1,448     None  None
# Anguilla                North America   5,007     None    23
# China                            Asia  16,959  310,601    16
#
# [216 rows x 18 columns]

# %%
col_names = ["Total Cases","New Cases","Total Deaths","New Deaths","Total Recovered","Active"]
df = pd.DataFrame(dic).iloc[1:7,:].T
df.index_name = "country"
df.columns = col_names
df
# Out:
#                                    Total Cases   New Cases Total Deaths  \
# NaN                                      World  22,069,519      +26,133
# USA                                        USA   5,612,027         None
# Brazil                                  Brazil   3,363,235         None
# India                                    India   2,706,450       +4,846
# Russia                                  Russia     932,493       +4,748
# ...                                        ...         ...          ...
# 211                                 MS Zaandam           9         None
# British Virgin Islands  British Virgin Islands           9         None
# Saint Pierre Miquelon    Saint Pierre Miquelon           4         None
# Anguilla                              Anguilla           3         None
# China                                    China      84,871          +22
#
#                        New Deaths Total Recovered      Active
# NaN                       777,755            +679  14,807,868
# USA                      173,716             None   2,973,587
# Brazil                   108,654             None   2,478,494
# India                     51,955              +30   1,978,747
# Russia                    15,872             +132     742,628
# ...                           ...             ...         ...
# 211                            2             None        None
# British Virgin Islands         1             None           7
# Saint Pierre Miquelon                        None           1
# Anguilla                                     None           3
# China                      4,634             None      79,642
#
# [216 rows x 6 columns]

# %%
df.head()
# Out:
#        Total Cases   New Cases Total Deaths New Deaths Total Recovered  \
# NaN          World  22,069,519      +26,133    777,755            +679
# USA            USA   5,612,027         None   173,716             None
# Brazil      Brazil   3,363,235         None   108,654             None
# India        India   2,706,450       +4,846    51,955              +30
# Russia      Russia     932,493       +4,748    15,872             +132
#
#             Active
# NaN     14,807,868
# USA      2,973,587
# Brazil   2,478,494
# India    1,978,747
# Russia     742,628
